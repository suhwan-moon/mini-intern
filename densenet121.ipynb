# %%
# === Cell 1: Versions & reset ===
import os, random, gc, sys, numpy as np, tensorflow as tf
print("Python:", sys.version)
print("TensorFlow:", tf.__version__)
print("Keras image_data_format:", tf.keras.backend.image_data_format())  # 'channels_last' 여야 정상

# 재현성 + 세션 초기화
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
tf.keras.backend.clear_session(); gc.collect()

# GPU 확인
print("Physical GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# Python: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# TensorFlow: 2.19.0
# Keras image_data_format: channels_last
# Physical GPUs: []

# %%
# === Cell 2: Paths & constants ===
import os

DATA_ROOT = r"C:/Users/moont/Desktop/2025miniinterncode/lumbar_spinal_dataset"
TRAIN_DIR = os.path.join(DATA_ROOT, "training")
TEST_DIR  = os.path.join(DATA_ROOT, "testing")

CLASSES = ["Herniated_Disc", "No_Stenosis", "Thecal_Sac"]
IMG_SIZE = (200, 200)
INPUT_SHAPE = IMG_SIZE + (3,)   # 반드시 3채널
BATCH_SIZE = 32
VAL_SPLIT = 0.2

# EfficientNet 제외. 다음 중 선택:
BACKBONE = "densenet121"  # 'resnet50', 'densenet121', 'inceptionv3', 'mobilenetv2'

print("CLASSES:", CLASSES)
print("IMG_SIZE:", IMG_SIZE)
print("INPUT_SHAPE(should be 3ch):", INPUT_SHAPE)
assert INPUT_SHAPE[-1] == 3, "INPUT_SHAPE 마지막 채널이 3이 아닙니다!"
# Out:
# CLASSES: ['Herniated_Disc', 'No_Stenosis', 'Thecal_Sac']
# IMG_SIZE: (200, 200)
# INPUT_SHAPE(should be 3ch): (200, 200, 3)

# %%
# === Cell 3: Datasets (force RGB) ===
train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, labels="inferred", label_mode="int", class_names=CLASSES,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT, subset="training",
    seed=SEED, shuffle=True, color_mode="rgb"
)
val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR, labels="inferred", label_mode="int", class_names=CLASSES,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT, subset="validation",
    seed=SEED, shuffle=True, color_mode="rgb"
)
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR, labels="inferred", label_mode="int", class_names=CLASSES,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    shuffle=False, color_mode="rgb"
)

print(f"Batches -> Train:{len(train_ds_raw)}  Val:{len(val_ds_raw)}  Test:{len(test_ds_raw)}")

xb, yb = next(iter(train_ds_raw.take(1)))
print("첫 train 배치 shape:", xb.shape)  # (B, 200, 200, 3)
tf.debugging.assert_equal(tf.shape(xb)[-1], 3)
# Out:
# Found 4808 files belonging to 3 classes.
# Using 3847 files for training.
# Found 4808 files belonging to 3 classes.
# Using 961 files for validation.
# Found 1158 files belonging to 3 classes.
# Batches -> Train:121  Val:31  Test:37
# 첫 train 배치 shape: (32, 200, 200, 3)

# %%
# === Cell 4: Preprocess/Augment ===
from tensorflow.keras import layers

AUTOTUNE = tf.data.AUTOTUNE
augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
], name="augment")
rescale = layers.Rescaling(1./255, name="rescale")

def prepare(ds, training=False):
    if training:
        ds = ds.map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=AUTOTUNE)
    ds = ds.map(lambda x, y: (rescale(x), y), num_parallel_calls=AUTOTUNE)
    return ds.cache().prefetch(AUTOTUNE)

train_ds = prepare(train_ds_raw, training=True)
val_ds   = prepare(val_ds_raw,   training=False)
test_ds  = prepare(test_ds_raw,  training=False)

xb2, _ = next(iter(train_ds.take(1)))
print("전처리 후 배치 shape:", xb2.shape)  # (B, 200, 200, 3)
tf.debugging.assert_equal(tf.shape(xb2)[-1], 3)
# Out:
# 전처리 후 배치 shape: (32, 200, 200, 3)

# %%
# === Cell 5: Backbone builder (no EfficientNet) ===
from tensorflow.keras import applications as KApps

def build_backbone_force_rgb(name: str):
    name = name.lower()
    inp = tf.keras.Input(shape=INPUT_SHAPE, name="force_rgb_input")  # 3채널 고정

    if name == "mobilenetv2":
        base = KApps.MobileNetV2(include_top=False, weights="imagenet", input_tensor=inp)
    elif name == "resnet50":
        base = KApps.ResNet50(include_top=False, weights="imagenet", input_tensor=inp)
    elif name == "densenet121":
        base = KApps.DenseNet121(include_top=False, weights="imagenet", input_tensor=inp)
    elif name == "inceptionv3":
        base = KApps.InceptionV3(include_top=False, weights="imagenet", input_tensor=inp)
    else:
        raise ValueError(f"Unsupported backbone for this notebook: {name}")

    return base

# %%
# === Cell 6: backbone build + full model (explicit head, short summary) ===
from tensorflow.keras import layers, models
from collections import deque

def short_summary(model, tail=15):
    """model.summary()의 마지막 tail줄만 출력"""
    buf = []
    model.summary(print_fn=lambda x: buf.append(x))
    for line in deque(buf, maxlen=tail):
        print(line)

def build_deep_model_explicit(backbone_name,
                              input_shape=(200, 200, 3),
                              dropout_rate=0.2):
    # 1) 백본 (이미지넷, 3채널 강제) — Cell 5의 build_backbone_force_rgb 사용
    base = build_backbone_force_rgb(backbone_name)
    base.trainable = False  # Stage 1: 백본 고정

    # 2) 입력/백본 통과
    inputs = base.inputs[0]          # 강제 3채널 input_tensor
    x = base.outputs[0]              # 백본 출력 feature

    # 3) 분류기 헤드 (명시적으로 단계별 구성)
    x = layers.GlobalAveragePooling2D(name="gap")(x)

    # Block 1
    x = layers.Dense(1024, activation="relu", name="dense_1")(x)
    x = layers.BatchNormalization(name="bn_1")(x)
    x = layers.Dropout(dropout_rate, name="dropout_1")(x)

    # Block 2
    x = layers.Dense(512, activation="relu", name="dense_2")(x)
    x = layers.BatchNormalization(name="bn_2")(x)
    x = layers.Dropout(dropout_rate, name="dropout_2")(x)

    # Block 3
    x = layers.Dense(256, activation="relu", name="dense_3")(x)
    x = layers.BatchNormalization(name="bn_3")(x)
    x = layers.Dropout(dropout_rate, name="dropout_3")(x)

    # Block 4
    x = layers.Dense(128, activation="relu", name="dense_4")(x)
    x = layers.BatchNormalization(name="bn_4")(x)
    x = layers.Dropout(dropout_rate, name="dropout_4")(x)

    # Output
    outputs = layers.Dense(len(CLASSES), activation="softmax", name="output")(x)

    model = models.Model(inputs, outputs, name=f"{backbone_name}_deep_model")
    return model, base

# —— 모델 생성 & 짧은 summary 출력 ——
tf.keras.backend.clear_session()
model, base = build_deep_model_explicit(
    backbone_name=BACKBONE,        # 예: "mobilenetv2"
    input_shape=INPUT_SHAPE,
    dropout_rate=0.4
)

print("\n===== ✅ Backbone summary (short) =====")
short_summary(base, tail=15)

print("\n===== ✅ Full model summary (short) =====")
short_summary(model, tail=15)
# Out:
# ===== ✅ Backbone summary (short) =====
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "densenet121"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ force_rgb_input     │ (None, 200, 200,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 206, 206,  │          0 │ force_rgb_input[… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 100, 100,  │      9,408 │ zero_padding2d[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 100, 100,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 100, 100,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 102, 102,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1               │ (None, 50, 50,    │          0 │ zero_padding2d_1… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 50, 50,    │        256 │ pool1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_relu │ (None, 50, 50,    │          0 │ conv2_block1_0_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 50, 50,    │      8,192 │ conv2_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 50, 50,    │        512 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 50, 50,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_concat │ (None, 50, 50,    │          0 │ pool1[0][0],      │
# │ (Concatenate)       │ 96)               │            │ conv2_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_bn   │ (None, 50, 50,    │        384 │ conv2_block1_con… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_0_relu │ (None, 50, 50,    │          0 │ conv2_block2_0_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 50, 50,    │     12,288 │ conv2_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 50, 50,    │        512 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 50, 50,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_concat │ (None, 50, 50,    │          0 │ conv2_block1_con… │
# │ (Concatenate)       │ 128)              │            │ conv2_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_bn   │ (None, 50, 50,    │        512 │ conv2_block2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_0_relu │ (None, 50, 50,    │          0 │ conv2_block3_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 50, 50,    │     16,384 │ conv2_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 50, 50,    │        512 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 50, 50,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_concat │ (None, 50, 50,    │          0 │ conv2_block2_con… │
# │ (Concatenate)       │ 160)              │            │ conv2_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_bn   │ (None, 50, 50,    │        640 │ conv2_block3_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_0_relu │ (None, 50, 50,    │          0 │ conv2_block4_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_conv │ (None, 50, 50,    │     20,480 │ conv2_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_bn   │ (None, 50, 50,    │        512 │ conv2_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_1_relu │ (None, 50, 50,    │          0 │ conv2_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block4_concat │ (None, 50, 50,    │          0 │ conv2_block3_con… │
# │ (Concatenate)       │ 192)              │            │ conv2_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_bn   │ (None, 50, 50,    │        768 │ conv2_block4_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_0_relu │ (None, 50, 50,    │          0 │ conv2_block5_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_conv │ (None, 50, 50,    │     24,576 │ conv2_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_bn   │ (None, 50, 50,    │        512 │ conv2_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_1_relu │ (None, 50, 50,    │          0 │ conv2_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block5_concat │ (None, 50, 50,    │          0 │ conv2_block4_con… │
# │ (Concatenate)       │ 224)              │            │ conv2_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_bn   │ (None, 50, 50,    │        896 │ conv2_block5_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_0_relu │ (None, 50, 50,    │          0 │ conv2_block6_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_conv │ (None, 50, 50,    │     28,672 │ conv2_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_bn   │ (None, 50, 50,    │        512 │ conv2_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_1_relu │ (None, 50, 50,    │          0 │ conv2_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_2_conv │ (None, 50, 50,    │     36,864 │ conv2_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block6_concat │ (None, 50, 50,    │          0 │ conv2_block5_con… │
# │ (Concatenate)       │ 256)              │            │ conv2_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_bn            │ (None, 50, 50,    │      1,024 │ conv2_block6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_relu          │ (None, 50, 50,    │          0 │ pool2_bn[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_conv (Conv2D) │ (None, 50, 50,    │     32,768 │ pool2_relu[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool2_pool          │ (None, 25, 25,    │          0 │ pool2_conv[0][0]  │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 25, 25,    │        512 │ pool2_pool[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_relu │ (None, 25, 25,    │          0 │ conv3_block1_0_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 25, 25,    │     16,384 │ conv3_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 25, 25,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 25, 25,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_concat │ (None, 25, 25,    │          0 │ pool2_pool[0][0], │
# │ (Concatenate)       │ 160)              │            │ conv3_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_bn   │ (None, 25, 25,    │        640 │ conv3_block1_con… │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_0_relu │ (None, 25, 25,    │          0 │ conv3_block2_0_b… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 25, 25,    │     20,480 │ conv3_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 25, 25,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 25, 25,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_concat │ (None, 25, 25,    │          0 │ conv3_block1_con… │
# │ (Concatenate)       │ 192)              │            │ conv3_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_bn   │ (None, 25, 25,    │        768 │ conv3_block2_con… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_0_relu │ (None, 25, 25,    │          0 │ conv3_block3_0_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 25, 25,    │     24,576 │ conv3_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 25, 25,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 25, 25,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_concat │ (None, 25, 25,    │          0 │ conv3_block2_con… │
# │ (Concatenate)       │ 224)              │            │ conv3_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_bn   │ (None, 25, 25,    │        896 │ conv3_block3_con… │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_0_relu │ (None, 25, 25,    │          0 │ conv3_block4_0_b… │
# │ (Activation)        │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 25, 25,    │     28,672 │ conv3_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 25, 25,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 25, 25,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_concat │ (None, 25, 25,    │          0 │ conv3_block3_con… │
# │ (Concatenate)       │ 256)              │            │ conv3_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_bn   │ (None, 25, 25,    │      1,024 │ conv3_block4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_0_relu │ (None, 25, 25,    │          0 │ conv3_block5_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_conv │ (None, 25, 25,    │     32,768 │ conv3_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn   │ (None, 25, 25,    │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_relu │ (None, 25, 25,    │          0 │ conv3_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_concat │ (None, 25, 25,    │          0 │ conv3_block4_con… │
# │ (Concatenate)       │ 288)              │            │ conv3_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_bn   │ (None, 25, 25,    │      1,152 │ conv3_block5_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_0_relu │ (None, 25, 25,    │          0 │ conv3_block6_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_conv │ (None, 25, 25,    │     36,864 │ conv3_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn   │ (None, 25, 25,    │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_relu │ (None, 25, 25,    │          0 │ conv3_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_concat │ (None, 25, 25,    │          0 │ conv3_block5_con… │
# │ (Concatenate)       │ 320)              │            │ conv3_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_bn   │ (None, 25, 25,    │      1,280 │ conv3_block6_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_0_relu │ (None, 25, 25,    │          0 │ conv3_block7_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_conv │ (None, 25, 25,    │     40,960 │ conv3_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn   │ (None, 25, 25,    │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_relu │ (None, 25, 25,    │          0 │ conv3_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_concat │ (None, 25, 25,    │          0 │ conv3_block6_con… │
# │ (Concatenate)       │ 352)              │            │ conv3_block7_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_0_bn   │ (None, 25, 25,    │      1,408 │ conv3_block7_con… │
# │ (BatchNormalizatio… │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_0_relu │ (None, 25, 25,    │          0 │ conv3_block8_0_b… │
# │ (Activation)        │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_conv │ (None, 25, 25,    │     45,056 │ conv3_block8_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_bn   │ (None, 25, 25,    │        512 │ conv3_block8_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_relu │ (None, 25, 25,    │          0 │ conv3_block8_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block8_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_concat │ (None, 25, 25,    │          0 │ conv3_block7_con… │
# │ (Concatenate)       │ 384)              │            │ conv3_block8_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_0_bn   │ (None, 25, 25,    │      1,536 │ conv3_block8_con… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_0_relu │ (None, 25, 25,    │          0 │ conv3_block9_0_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_conv │ (None, 25, 25,    │     49,152 │ conv3_block9_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_bn   │ (None, 25, 25,    │        512 │ conv3_block9_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_1_relu │ (None, 25, 25,    │          0 │ conv3_block9_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_2_conv │ (None, 25, 25,    │     36,864 │ conv3_block9_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block9_concat │ (None, 25, 25,    │          0 │ conv3_block8_con… │
# │ (Concatenate)       │ 416)              │            │ conv3_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_0_bn  │ (None, 25, 25,    │      1,664 │ conv3_block9_con… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_0_re… │ (None, 25, 25,    │          0 │ conv3_block10_0_… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_co… │ (None, 25, 25,    │     53,248 │ conv3_block10_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_bn  │ (None, 25, 25,    │        512 │ conv3_block10_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_1_re… │ (None, 25, 25,    │          0 │ conv3_block10_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_2_co… │ (None, 25, 25,    │     36,864 │ conv3_block10_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block10_conc… │ (None, 25, 25,    │          0 │ conv3_block9_con… │
# │ (Concatenate)       │ 448)              │            │ conv3_block10_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_0_bn  │ (None, 25, 25,    │      1,792 │ conv3_block10_co… │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_0_re… │ (None, 25, 25,    │          0 │ conv3_block11_0_… │
# │ (Activation)        │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_co… │ (None, 25, 25,    │     57,344 │ conv3_block11_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_bn  │ (None, 25, 25,    │        512 │ conv3_block11_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_1_re… │ (None, 25, 25,    │          0 │ conv3_block11_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_2_co… │ (None, 25, 25,    │     36,864 │ conv3_block11_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block11_conc… │ (None, 25, 25,    │          0 │ conv3_block10_co… │
# │ (Concatenate)       │ 480)              │            │ conv3_block11_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_0_bn  │ (None, 25, 25,    │      1,920 │ conv3_block11_co… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_0_re… │ (None, 25, 25,    │          0 │ conv3_block12_0_… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_co… │ (None, 25, 25,    │     61,440 │ conv3_block12_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_bn  │ (None, 25, 25,    │        512 │ conv3_block12_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_1_re… │ (None, 25, 25,    │          0 │ conv3_block12_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_2_co… │ (None, 25, 25,    │     36,864 │ conv3_block12_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block12_conc… │ (None, 25, 25,    │          0 │ conv3_block11_co… │
# │ (Concatenate)       │ 512)              │            │ conv3_block12_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_bn            │ (None, 25, 25,    │      2,048 │ conv3_block12_co… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_relu          │ (None, 25, 25,    │          0 │ pool3_bn[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_conv (Conv2D) │ (None, 25, 25,    │    131,072 │ pool3_relu[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool3_pool          │ (None, 12, 12,    │          0 │ pool3_conv[0][0]  │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 12, 12,    │      1,024 │ pool3_pool[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_relu │ (None, 12, 12,    │          0 │ conv4_block1_0_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 12, 12,    │     32,768 │ conv4_block1_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 12, 12,    │        512 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 12, 12,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_concat │ (None, 12, 12,    │          0 │ pool3_pool[0][0], │
# │ (Concatenate)       │ 288)              │            │ conv4_block1_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_0_bn   │ (None, 12, 12,    │      1,152 │ conv4_block1_con… │
# │ (BatchNormalizatio… │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_0_relu │ (None, 12, 12,    │          0 │ conv4_block2_0_b… │
# │ (Activation)        │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 12, 12,    │     36,864 │ conv4_block2_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 12, 12,    │        512 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 12, 12,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_concat │ (None, 12, 12,    │          0 │ conv4_block1_con… │
# │ (Concatenate)       │ 320)              │            │ conv4_block2_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_0_bn   │ (None, 12, 12,    │      1,280 │ conv4_block2_con… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_0_relu │ (None, 12, 12,    │          0 │ conv4_block3_0_b… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 12, 12,    │     40,960 │ conv4_block3_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 12, 12,    │        512 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 12, 12,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_concat │ (None, 12, 12,    │          0 │ conv4_block2_con… │
# │ (Concatenate)       │ 352)              │            │ conv4_block3_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_0_bn   │ (None, 12, 12,    │      1,408 │ conv4_block3_con… │
# │ (BatchNormalizatio… │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_0_relu │ (None, 12, 12,    │          0 │ conv4_block4_0_b… │
# │ (Activation)        │ 352)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 12, 12,    │     45,056 │ conv4_block4_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 12, 12,    │        512 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 12, 12,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_concat │ (None, 12, 12,    │          0 │ conv4_block3_con… │
# │ (Concatenate)       │ 384)              │            │ conv4_block4_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_0_bn   │ (None, 12, 12,    │      1,536 │ conv4_block4_con… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_0_relu │ (None, 12, 12,    │          0 │ conv4_block5_0_b… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 12, 12,    │     49,152 │ conv4_block5_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 12, 12,    │        512 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 12, 12,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_concat │ (None, 12, 12,    │          0 │ conv4_block4_con… │
# │ (Concatenate)       │ 416)              │            │ conv4_block5_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_0_bn   │ (None, 12, 12,    │      1,664 │ conv4_block5_con… │
# │ (BatchNormalizatio… │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_0_relu │ (None, 12, 12,    │          0 │ conv4_block6_0_b… │
# │ (Activation)        │ 416)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 12, 12,    │     53,248 │ conv4_block6_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 12, 12,    │        512 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 12, 12,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_concat │ (None, 12, 12,    │          0 │ conv4_block5_con… │
# │ (Concatenate)       │ 448)              │            │ conv4_block6_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_0_bn   │ (None, 12, 12,    │      1,792 │ conv4_block6_con… │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_0_relu │ (None, 12, 12,    │          0 │ conv4_block7_0_b… │
# │ (Activation)        │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_conv │ (None, 12, 12,    │     57,344 │ conv4_block7_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_bn   │ (None, 12, 12,    │        512 │ conv4_block7_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_relu │ (None, 12, 12,    │          0 │ conv4_block7_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block7_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_concat │ (None, 12, 12,    │          0 │ conv4_block6_con… │
# │ (Concatenate)       │ 480)              │            │ conv4_block7_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_0_bn   │ (None, 12, 12,    │      1,920 │ conv4_block7_con… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_0_relu │ (None, 12, 12,    │          0 │ conv4_block8_0_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_conv │ (None, 12, 12,    │     61,440 │ conv4_block8_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_bn   │ (None, 12, 12,    │        512 │ conv4_block8_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_1_relu │ (None, 12, 12,    │          0 │ conv4_block8_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block8_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block8_concat │ (None, 12, 12,    │          0 │ conv4_block7_con… │
# │ (Concatenate)       │ 512)              │            │ conv4_block8_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_0_bn   │ (None, 12, 12,    │      2,048 │ conv4_block8_con… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_0_relu │ (None, 12, 12,    │          0 │ conv4_block9_0_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_conv │ (None, 12, 12,    │     65,536 │ conv4_block9_0_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_bn   │ (None, 12, 12,    │        512 │ conv4_block9_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_1_relu │ (None, 12, 12,    │          0 │ conv4_block9_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_2_conv │ (None, 12, 12,    │     36,864 │ conv4_block9_1_r… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block9_concat │ (None, 12, 12,    │          0 │ conv4_block8_con… │
# │ (Concatenate)       │ 544)              │            │ conv4_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block10_0_bn  │ (None, 12, 12,    │      2,176 │ conv4_block9_con… │
# │ (BatchNormalizatio… │ 544)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block10_0_re… │ (None, 12, 12,    │          0 │ conv4_block10_0_… │
# │ (Activation)        │ 544)              │            │                   │
# ...
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_0_relu │ (None, 6, 6, 768) │          0 │ conv5_block9_0_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_conv │ (None, 6, 6, 128) │     98,304 │ conv5_block9_0_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_bn   │ (None, 6, 6, 128) │        512 │ conv5_block9_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_1_relu │ (None, 6, 6, 128) │          0 │ conv5_block9_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_2_conv │ (None, 6, 6, 32)  │     36,864 │ conv5_block9_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block9_concat │ (None, 6, 6, 800) │          0 │ conv5_block8_con… │
# │ (Concatenate)       │                   │            │ conv5_block9_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_0_bn  │ (None, 6, 6, 800) │      3,200 │ conv5_block9_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_0_re… │ (None, 6, 6, 800) │          0 │ conv5_block10_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_co… │ (None, 6, 6, 128) │    102,400 │ conv5_block10_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block10_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block10_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block10_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block10_conc… │ (None, 6, 6, 832) │          0 │ conv5_block9_con… │
# │ (Concatenate)       │                   │            │ conv5_block10_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_0_bn  │ (None, 6, 6, 832) │      3,328 │ conv5_block10_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_0_re… │ (None, 6, 6, 832) │          0 │ conv5_block11_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_co… │ (None, 6, 6, 128) │    106,496 │ conv5_block11_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block11_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block11_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block11_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block11_conc… │ (None, 6, 6, 864) │          0 │ conv5_block10_co… │
# │ (Concatenate)       │                   │            │ conv5_block11_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_0_bn  │ (None, 6, 6, 864) │      3,456 │ conv5_block11_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_0_re… │ (None, 6, 6, 864) │          0 │ conv5_block12_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_co… │ (None, 6, 6, 128) │    110,592 │ conv5_block12_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block12_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block12_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block12_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block12_conc… │ (None, 6, 6, 896) │          0 │ conv5_block11_co… │
# │ (Concatenate)       │                   │            │ conv5_block12_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_0_bn  │ (None, 6, 6, 896) │      3,584 │ conv5_block12_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_0_re… │ (None, 6, 6, 896) │          0 │ conv5_block13_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_co… │ (None, 6, 6, 128) │    114,688 │ conv5_block13_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block13_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block13_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block13_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block13_conc… │ (None, 6, 6, 928) │          0 │ conv5_block12_co… │
# │ (Concatenate)       │                   │            │ conv5_block13_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_0_bn  │ (None, 6, 6, 928) │      3,712 │ conv5_block13_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_0_re… │ (None, 6, 6, 928) │          0 │ conv5_block14_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_co… │ (None, 6, 6, 128) │    118,784 │ conv5_block14_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block14_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block14_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block14_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block14_conc… │ (None, 6, 6, 960) │          0 │ conv5_block13_co… │
# │ (Concatenate)       │                   │            │ conv5_block14_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_bn  │ (None, 6, 6, 960) │      3,840 │ conv5_block14_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_0_re… │ (None, 6, 6, 960) │          0 │ conv5_block15_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_co… │ (None, 6, 6, 128) │    122,880 │ conv5_block15_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block15_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block15_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block15_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block15_conc… │ (None, 6, 6, 992) │          0 │ conv5_block14_co… │
# │ (Concatenate)       │                   │            │ conv5_block15_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_bn  │ (None, 6, 6, 992) │      3,968 │ conv5_block15_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_0_re… │ (None, 6, 6, 992) │          0 │ conv5_block16_0_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_co… │ (None, 6, 6, 128) │    126,976 │ conv5_block16_0_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_bn  │ (None, 6, 6, 128) │        512 │ conv5_block16_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_1_re… │ (None, 6, 6, 128) │          0 │ conv5_block16_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_2_co… │ (None, 6, 6, 32)  │     36,864 │ conv5_block16_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block16_conc… │ (None, 6, 6,      │          0 │ conv5_block15_co… │
# │ (Concatenate)       │ 1024)             │            │ conv5_block16_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn                  │ (None, 6, 6,      │      4,096 │ conv5_block16_co… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu (Activation)   │ (None, 6, 6,      │          0 │ bn[0][0]          │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 1024)      │          0 │ relu[0][0]        │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │  1,049,600 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_1                │ (None, 1024)      │      4,096 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ bn_1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    524,800 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_2                │ (None, 512)       │      2,048 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ bn_2[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_3                │ (None, 256)       │      1,024 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ bn_3[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_4                │ (None, 128)       │        512 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ bn_4[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 3)         │        387 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,784,195 (33.51 MB)
#  Trainable params: 1,742,851 (6.65 MB)
#  Non-trainable params: 7,041,344 (26.86 MB)

# %%
# === Cell 8: two-stage training (EarlyStopping 적용) ===
from tensorflow.keras.callbacks import EarlyStopping

def train_two_stage(model, base, train_ds, val_ds,
                    epochs_stage1=30, epochs_stage2=20,
                    finetune_unfreeze_top_k=20,
                    lr_stage1=1e-3, lr_stage2=1e-4,
                    patience=5, monitor="val_loss"):

    early_stop = EarlyStopping(
        monitor=monitor, patience=patience, restore_best_weights=True, verbose=1
    )

    # Stage 1 — 백본 고정
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_stage1),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    print(f"\n[Stage 1] up to {epochs_stage1} epochs (monitor: {monitor}, patience={patience})")
    hist1 = model.fit(
        train_ds, validation_data=val_ds,
        epochs=epochs_stage1, callbacks=[early_stop], verbose=1
    )

    # Stage 2 — 백본 일부 파인튜닝
    for layer in base.layers[-finetune_unfreeze_top_k:]:
        layer.trainable = True

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_stage2),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    print(f"\n[Stage 2] unfreeze top {finetune_unfreeze_top_k} layers, up to {epochs_stage2} epochs")
    hist2 = model.fit(
        train_ds, validation_data=val_ds,
        epochs=epochs_stage2, callbacks=[early_stop], verbose=1
    )
    return hist1, hist2

# %%
# === Cell 9: evaluation (정확도/혼동행렬/민감도·특이도/리포트/ROC-AUC) ===
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score
from sklearn.preprocessing import label_binarize
import numpy as np

def evaluate_full(model, test_ds, class_names):
    # 예측
    y_true, y_prob = [], []
    for xb, yb in test_ds:
        preds = model.predict(xb, verbose=0)
        y_prob.append(preds)
        y_true.extend(yb.numpy())
    y_true = np.array(y_true)
    y_prob = np.vstack(y_prob)
    y_pred = np.argmax(y_prob, axis=1)

    # 정확도
    acc = accuracy_score(y_true, y_pred)
    print(f"\n✅ 전체 정확도: {acc:.4f}")

    # 혼동행렬
    cm = confusion_matrix(y_true, y_pred, labels=list(range(len(class_names))))
    print("\n[혼동 행렬] (rows=true, cols=pred)\n", cm)

    # 분류 리포트
    print("\n[분류 리포트: Precision / Recall / F1]")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    # 민감도(Sensitivity), 특이도(Specificity)
    TP = np.diag(cm)
    FN = cm.sum(axis=1) - TP
    FP = cm.sum(axis=0) - TP
    TN = cm.sum() - (TP + FP + FN)
    sensitivity = TP / (TP + FN + 1e-8)
    specificity = TN / (TN + FP + 1e-8)
    print("\n[클래스별 민감도 / 특이도]")
    for i, cls in enumerate(class_names):
        print(f"{cls:15s} | 민감도 {sensitivity[i]:.4f} | 특이도 {specificity[i]:.4f}")

    # ROC-AUC (One-vs-Rest)
    y_true_bin = label_binarize(y_true, classes=list(range(len(class_names))))
    auc_macro = roc_auc_score(y_true_bin, y_prob, multi_class="ovr", average="macro")
    auc_weighted = roc_auc_score(y_true_bin, y_prob, multi_class="ovr", average="weighted")
    print(f"\n[ROC-AUC] macro={auc_macro:.4f} | weighted={auc_weighted:.4f}")

# %%
# === Cell 10: train & evaluate (에폭 확대 + 얼리스타핑) ===
_ = train_two_stage(
    model, base,
    train_ds=train_ds, val_ds=val_ds,
    epochs_stage1=30, epochs_stage2=20,     # 반복 횟수 확대
    finetune_unfreeze_top_k=20,             # 상위 20개 레이어 파인튜닝
    lr_stage1=1e-3, lr_stage2=1e-4,
    patience=5, monitor="val_loss"          # 얼리스타핑 기준/인내심
)

evaluate_full(model, test_ds, class_names=CLASSES)
# Out:
# [Stage 1] up to 30 epochs (monitor: val_loss, patience=5)
# Epoch 1/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.3655 - loss: 1.5378 - val_accuracy: 0.4089 - val_loss: 1.1436
# Epoch 2/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.4053 - loss: 1.2589 - val_accuracy: 0.4370 - val_loss: 1.0642
# Epoch 3/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.4136 - loss: 1.1777 - val_accuracy: 0.4589 - val_loss: 1.0515
# Epoch 4/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 121s 998ms/step - accuracy: 0.4250 - loss: 1.1182 - val_accuracy: 0.4641 - val_loss: 1.0330
# Epoch 5/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 116s 958ms/step - accuracy: 0.4663 - loss: 1.0583 - val_accuracy: 0.4818 - val_loss: 1.0109
# Epoch 6/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 112s 922ms/step - accuracy: 0.4622 - loss: 1.0394 - val_accuracy: 0.5213 - val_loss: 0.9788
# Epoch 7/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 916ms/step - accuracy: 0.4804 - loss: 1.0172 - val_accuracy: 0.5057 - val_loss: 0.9891
# Epoch 8/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 914ms/step - accuracy: 0.5014 - loss: 1.0023 - val_accuracy: 0.5213 - val_loss: 0.9540
# Epoch 9/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5165 - loss: 0.9811 - val_accuracy: 0.5193 - val_loss: 0.9616
# Epoch 10/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5357 - loss: 0.9665 - val_accuracy: 0.5525 - val_loss: 0.9413
# Epoch 11/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 917ms/step - accuracy: 0.5451 - loss: 0.9516 - val_accuracy: 0.5224 - val_loss: 0.9595
# Epoch 12/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 914ms/step - accuracy: 0.5438 - loss: 0.9527 - val_accuracy: 0.5359 - val_loss: 0.9493
# Epoch 13/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 918ms/step - accuracy: 0.5464 - loss: 0.9488 - val_accuracy: 0.5432 - val_loss: 0.9365
# Epoch 14/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 914ms/step - accuracy: 0.5485 - loss: 0.9332 - val_accuracy: 0.5276 - val_loss: 0.9723
# Epoch 15/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 912ms/step - accuracy: 0.5495 - loss: 0.9341 - val_accuracy: 0.5317 - val_loss: 1.0065
# Epoch 16/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5485 - loss: 0.9305 - val_accuracy: 0.5047 - val_loss: 1.0334
# Epoch 17/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 911ms/step - accuracy: 0.5586 - loss: 0.9246 - val_accuracy: 0.5453 - val_loss: 0.9311
# Epoch 18/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 911ms/step - accuracy: 0.5560 - loss: 0.9258 - val_accuracy: 0.5817 - val_loss: 0.9127
# Epoch 19/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5716 - loss: 0.9097 - val_accuracy: 0.5317 - val_loss: 0.9758
# Epoch 20/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5802 - loss: 0.8988 - val_accuracy: 0.5505 - val_loss: 0.9613
# Epoch 21/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 918ms/step - accuracy: 0.5740 - loss: 0.9069 - val_accuracy: 0.5359 - val_loss: 0.9506
# Epoch 22/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 914ms/step - accuracy: 0.5823 - loss: 0.8941 - val_accuracy: 0.5921 - val_loss: 0.9060
# Epoch 23/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 112s 923ms/step - accuracy: 0.5885 - loss: 0.8966 - val_accuracy: 0.5224 - val_loss: 1.0314
# Epoch 24/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 112s 923ms/step - accuracy: 0.6002 - loss: 0.8793 - val_accuracy: 0.5702 - val_loss: 0.8957
# Epoch 25/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 915ms/step - accuracy: 0.5942 - loss: 0.8827 - val_accuracy: 0.5702 - val_loss: 0.9212
# Epoch 26/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 913ms/step - accuracy: 0.5929 - loss: 0.8824 - val_accuracy: 0.5338 - val_loss: 0.9579
# Epoch 27/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 914ms/step - accuracy: 0.6033 - loss: 0.8626 - val_accuracy: 0.5744 - val_loss: 0.9202
# Epoch 28/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 110s 913ms/step - accuracy: 0.6122 - loss: 0.8619 - val_accuracy: 0.5734 - val_loss: 0.9108
# Epoch 29/30
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 111s 916ms/step - accuracy: 0.6075 - loss: 0.8656 - val_accuracy: 0.5369 - val_loss: 0.9980
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 24.
#
# [Stage 2] unfreeze top 20 layers, up to 20 epochs
# Epoch 1/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 131s 993ms/step - accuracy: 0.5911 - loss: 0.8853 - val_accuracy: 0.5754 - val_loss: 0.9235
# Epoch 2/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 115s 950ms/step - accuracy: 0.6140 - loss: 0.8511 - val_accuracy: 0.5911 - val_loss: 0.8832
# Epoch 3/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 114s 946ms/step - accuracy: 0.6392 - loss: 0.8179 - val_accuracy: 0.5848 - val_loss: 0.8735
# Epoch 4/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 115s 947ms/step - accuracy: 0.6280 - loss: 0.8173 - val_accuracy: 0.6139 - val_loss: 0.8511
# Epoch 5/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 115s 949ms/step - accuracy: 0.6449 - loss: 0.7891 - val_accuracy: 0.6067 - val_loss: 0.8629
# Epoch 6/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 114s 945ms/step - accuracy: 0.6639 - loss: 0.7766 - val_accuracy: 0.6181 - val_loss: 0.8260
# Epoch 7/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 115s 953ms/step - accuracy: 0.6660 - loss: 0.7584 - val_accuracy: 0.6400 - val_loss: 0.8209
# Epoch 8/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 120s 990ms/step - accuracy: 0.6707 - loss: 0.7444 - val_accuracy: 0.6337 - val_loss: 0.8214
# Epoch 9/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 116s 963ms/step - accuracy: 0.6891 - loss: 0.7127 - val_accuracy: 0.6389 - val_loss: 0.8197
# Epoch 10/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 115s 952ms/step - accuracy: 0.7151 - loss: 0.6765 - val_accuracy: 0.6285 - val_loss: 0.8227
# Epoch 11/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 119s 983ms/step - accuracy: 0.7060 - loss: 0.6838 - val_accuracy: 0.6733 - val_loss: 0.7770
# Epoch 12/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 116s 961ms/step - accuracy: 0.7281 - loss: 0.6448 - val_accuracy: 0.6483 - val_loss: 0.8194
# Epoch 13/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 118s 975ms/step - accuracy: 0.7367 - loss: 0.6364 - val_accuracy: 0.6691 - val_loss: 0.7815
# Epoch 14/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 116s 962ms/step - accuracy: 0.7424 - loss: 0.6073 - val_accuracy: 0.6920 - val_loss: 0.7772
# Epoch 15/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 117s 964ms/step - accuracy: 0.7700 - loss: 0.5651 - val_accuracy: 0.6618 - val_loss: 0.8049
# Epoch 16/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.7715 - loss: 0.5733 - val_accuracy: 0.6587 - val_loss: 0.8182
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# ✅ 전체 정확도: 0.3972
#
# [혼동 행렬] (rows=true, cols=pred)
#  [[181  41  35]
#  [107 136  46]
#  [318 151 143]]
#
# [분류 리포트: Precision / Recall / F1]
#                 precision    recall  f1-score   support
#
# Herniated_Disc     0.2987    0.7043    0.4195       257
#    No_Stenosis     0.4146    0.4706    0.4408       289
#     Thecal_Sac     0.6384    0.2337    0.3421       612
#
#       accuracy                         0.3972      1158
#      macro avg     0.4506    0.4695    0.4008      1158
#   weighted avg     0.5072    0.3972    0.3839      1158
#
#
# [클래스별 민감도 / 특이도]
# Herniated_Disc  | 민감도 0.7043 | 특이도 0.5283
# No_Stenosis     | 민감도 0.4706 | 특이도 0.7791
# Thecal_Sac      | 민감도 0.2337 | 특이도 0.8516
#
# [ROC-AUC] macro=0.6318 | weighted=0.6053
